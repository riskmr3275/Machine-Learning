# %%
import pandas as pd

# %%
df=pd.read_csv('aug_train.csv')

# %%
df.head(2)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

newDf=pd.read_csv(data)

# %%
newDf.tail(5)
# Out:
#        Country         Region
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA

# %%
# pd.read_csv('movie_titles_metadata.tsv', sep='\t', skiprows=[0, 1])
pd.read_csv('movie_titles_metadata.tsv', sep='\t').head()
# Out:
#    m0  10 things i hate about you  1999  6.90     62847  \
# 0  m1  1492: conquest of paradise  1992   6.2   10421.0
# 1  m2                  15 minutes  2001   6.1   25854.0
# 2  m3       2001: a space odyssey  1968   8.4  163227.0
# 3  m4                     48 hrs.  1982   6.9   22289.0
# 4  m5           the fifth element  1997   7.5  133756.0
#
#                                 ['comedy' 'romance']
# 0        ['adventure' 'biography' 'drama' 'history']
# 1              ['action' 'crime' 'drama' 'thriller']
# 2                   ['adventure' 'mystery' 'sci-fi']
# 3     ['action' 'comedy' 'crime' 'drama' 'thriller']
# 4  ['action' 'adventure' 'romance' 'sci-fi' 'thri...

# %%
pd.read_csv('movie_titles_metadata.tsv', sep='\t', names=["sno","name","release_year","rating","votes","generes"]).head()
# Out:
#   sno                        name release_year  rating     votes  \
# 0  m0  10 things i hate about you         1999     6.9   62847.0
# 1  m1  1492: conquest of paradise         1992     6.2   10421.0
# 2  m2                  15 minutes         2001     6.1   25854.0
# 3  m3       2001: a space odyssey         1968     8.4  163227.0
# 4  m4                     48 hrs.         1982     6.9   22289.0
#
#                                           generes
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
pd.read_csv('aug_train.csv',index_col='city').head()
# Out:
#           enrollee_id  city_development_index gender      relevent_experience  \
# city
# city_103         8949                   0.920   Male  Has relevent experience
# city_40         29725                   0.776   Male   No relevent experience
# city_21         11561                   0.624    NaN   No relevent experience
# city_115        33241                   0.789    NaN   No relevent experience
# city_162          666                   0.767   Male  Has relevent experience
#
#          enrolled_university education_level major_discipline experience  \
# city
# city_103       no_enrollment        Graduate             STEM        >20
# city_40        no_enrollment        Graduate             STEM         15
# city_21     Full time course        Graduate             STEM          5
# city_115                 NaN        Graduate  Business Degree         <1
# city_162       no_enrollment         Masters             STEM        >20
#
# ...

# %%
pd.read_csv('aug_train.csv',header=10)
# Out:
#          699  city_103   0.92 Unnamed: 3  Has relevent experience  \
# 0      29452   city_21  0.624        NaN   No relevent experience
# 1      23853  city_103  0.920       Male  Has relevent experience
# 2      25619   city_61  0.913       Male  Has relevent experience
# 3       5826   city_21  0.624       Male   No relevent experience
# 4       8722   city_21  0.624        NaN   No relevent experience
# ...      ...       ...    ...        ...                      ...
# 19143   7386  city_173  0.878       Male   No relevent experience
# 19144  31398  city_103  0.920       Male  Has relevent experience
# 19145  24576  city_103  0.920       Male  Has relevent experience
# 19146   5756   city_65  0.802       Male  Has relevent experience
# 19147  23834   city_67  0.855        NaN   No relevent experience
#
#           no_enrollment        Graduate        STEM   17     10000+  Pvt Ltd  \
# 0      Full time course     High School         NaN    2        NaN      NaN
# ...

# %%
pd.read_csv('aug_train.csv',skipfooter=209,engine='python')
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0             8949  city_103                   0.920    Male
# 1            29725   city_40                   0.776    Male
# 2            11561   city_21                   0.624     NaN
# 3            33241  city_115                   0.789     NaN
# 4              666  city_162                   0.767    Male
# ...            ...       ...                     ...     ...
# 18944         2678  city_104                   0.924     NaN
# 18945        19078   city_16                   0.910  Female
# 18946        26999   city_21                   0.624    Male
# 18947        30261  city_160                   0.920    Male
# 18948        17108  city_160                   0.920    Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('aug_train.csv',usecols=['gender'])
# Out:
#       gender
# 0       Male
# 1       Male
# 2        NaN
# 3        NaN
# 4       Male
# ...      ...
# 19153   Male
# 19154   Male
# 19155   Male
# 19156   Male
# 19157    NaN
#
# [19158 rows x 1 columns]

# %%
gender_series1=pd.read_csv('aug_train.csv',usecols=['gender'])

# %%
gender_series = gender_series1['gender']

# %%
gender_series
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %%
gender_series1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  14650 non-null  object
# dtypes: object(1)
# memory usage: 149.8+ KB
